# %%
import onnxruntime as ort

print(ort.get_available_providers())

# %%
# !find $CONDA_PREFIX -name "libcublasLt.so*" 2>/dev/null
# !find $CONDA_PREFIX -name "libcudnn.so*" 2>/dev/null
# !find $CONDA_PREFIX -name "libcurand.so*" 2>/dev/null
# !find $CONDA_PREFIX -name "libcufft.so*" 2>/dev/null
# !find $CONDA_PREFIX -name "libcudart.so*" 2>/dev/null
