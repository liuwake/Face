# %% [markdown]
# - https://www.insightface.ai/zh#integrations

# %%
# !conda create -n ifpy38 python=3.8 ipykernel -y

# %%
# !pip install nvidia-cuda-runtime-cu11 nvidia-cudnn-cu11==8.6.0.163 \
    nvidia-curand-cu11 nvidia-cufft-cu11  \
    onnxruntime-gpu==1.18.1

# %%
! [ ! -e /kaggle/temp/insightface/python-package ] \
    && mkdir -p /kaggle/temp/ \
    && git clone https://gh-proxy.com/https://github.com/deepinsight/insightface.git \
    /kaggle/temp/insightface
# !cd /kaggle/temp/insightface/python-package/ \
    && pip install .

# %%
# %%sh
# SITE_PACKAGES=$(python -c "import site; print(site.getsitepackages()[0])")
# LD_LIBRARY_PATH=\
# ${SITE_PACKAGES}/nvidia/cublas/lib:\
# ${SITE_PACKAGES}/nvidia/cudnn/lib:\
# ${SITE_PACKAGES}/nvidia/curand/lib:\
# ${SITE_PACKAGES}/nvidia/cufft/lib:\
# ${SITE_PACKAGES}/nvidia/cuda_runtime/lib:$LD_LIBRARY_PATH \
# python demo.py
