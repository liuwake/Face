# %% [markdown]
# ## insatll isf python

# %% [markdown]
# ### 0.0 uninstall

# %%
# %pip uninstall inspireface -y
# Out:
# Found existing installation: inspireface 1.2.3
# Uninstalling inspireface-1.2.3:
#   Successfully uninstalled inspireface-1.2.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 0.1 Install via pip (Recommended)

# %%
# %pip install inspireface click
# Out:
# Collecting inspireface
#   Using cached inspireface-1.2.3.post5-cp38-cp38-manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from inspireface) (1.24.4)
# Requirement already satisfied: loguru in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from inspireface) (0.7.3)
# Requirement already satisfied: filelock in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/filelock-3.29.0-py3.8.egg (from inspireface) (3.29.0)
# Requirement already satisfied: modelscope in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/modelscope-1.36.3-py3.8.egg (from inspireface) (1.36.3)
# Requirement already satisfied: packaging in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from modelscope->inspireface) (24.1)
# Requirement already satisfied: requests>=2.25 in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from modelscope->inspireface) (2.32.4)
# Requirement already satisfied: setuptools in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from modelscope->inspireface) (75.1.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from modelscope->inspireface) (4.67.3)
# Requirement already satisfied: urllib3>=1.26 in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from modelscope->inspireface) (2.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from requests>=2.25->modelscope->inspireface) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from requests>=2.25->modelscope->inspireface) (3.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from requests>=2.25->modelscope->inspireface) (2026.4.22)
# Using cached inspireface-1.2.3.post5-cp38-cp38-manylinux2014_x86_64.whl (2.9 MB)
# Installing collected packages: inspireface
# Successfully installed inspireface-1.2.3.post5
# Note: you may need to restart the kernel to use updated packages.

# %%
# cpu to inspireface
# !cd /kaggle/temp/InspireFace/python \
    && mkdir -p /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface/modules/core/libs/linux/x64/ \
    && cp ../build/inspireface-linux/InspireFace/lib/libInspireFace.so \
    /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface/modules/core/libs/linux/x64/

# %%
# gpu to inspireface
# !cd /kaggle/temp/InspireFace/python \
    && mkdir -p /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface/modules/core/libs/linux/x64/ \
    && cp ../build/inspireface-linux-tensorrt-cuda12.2_ubuntu22.04/InspireFace/lib/libInspireFace.so \
    /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface/modules/core/libs/linux/x64/

# %% [markdown]
# ### Manual Installation

# %%
# %pip install loguru tqdm opencv-python click
# Out:
# Requirement already satisfied: loguru in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (0.7.3)
# Requirement already satisfied: tqdm in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (4.67.3)
# Requirement already satisfied: opencv-python in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (4.13.0.92)
# Requirement already satisfied: numpy<2.0 in /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages (from opencv-python) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !cd /kaggle/temp/InspireFace/python \
    && python setup.py install
# Out:
# Building for system: linux, arch: x64
# running install
# /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing inspireface.egg-info/PKG-INFO
# writing dependency_links to inspireface.egg-info/dependency_links.txt
# writing requirements to inspireface.egg-info/requires.txt
# writing top-level names to inspireface.egg-info/top_level.txt
# reading manifest file 'inspireface.egg-info/SOURCES.txt'
# writing manifest file 'inspireface.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying test/test_settings.py -> build/lib/test
# copying test/__init__.py -> build/lib/test
# copying test/test_utilis.py -> build/lib/test
# copying inspireface/__init__.py -> build/lib/inspireface
# copying inspireface/param.py -> build/lib/inspireface
# copying test/integration/__init__.py -> build/lib/test/integration
# copying test/unit/__init__.py -> build/lib/test/unit
# copying test/unit/test_tracker_module.py -> build/lib/test/unit
# copying test/unit/test_base_module.py -> build/lib/test/unit
# copying test/unit/test_recognition_module.py -> build/lib/test/unit
# copying test/performance/__init__.py -> build/lib/test/performance
# copying test/performance/test_lfw_precision.py -> build/lib/test/performance
# copying inspireface/modules/herror.py -> build/lib/inspireface/modules
# copying inspireface/modules/__init__.py -> build/lib/inspireface/modules
# copying inspireface/modules/exception.py -> build/lib/inspireface/modules
# copying inspireface/modules/inspireface.py -> build/lib/inspireface/modules
# copying inspireface/modules/core/native.py -> build/lib/inspireface/modules/core
# copying inspireface/modules/core/__init__.py -> build/lib/inspireface/modules/core
# copying inspireface/modules/utils/resource.py -> build/lib/inspireface/modules/utils
# copying inspireface/modules/utils/__init__.py -> build/lib/inspireface/modules/utils
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/inspireface
# copying build/lib/inspireface/param.py -> build/bdist.linux-x86_64/egg/inspireface
# creating build/bdist.linux-x86_64/egg/inspireface/modules
# creating build/bdist.linux-x86_64/egg/inspireface/modules/utils
# copying build/lib/inspireface/modules/utils/__init__.py -> build/bdist.linux-x86_64/egg/inspireface/modules/utils
# copying build/lib/inspireface/modules/utils/resource.py -> build/bdist.linux-x86_64/egg/inspireface/modules/utils
# copying build/lib/inspireface/modules/exception.py -> build/bdist.linux-x86_64/egg/inspireface/modules
# copying build/lib/inspireface/modules/herror.py -> build/bdist.linux-x86_64/egg/inspireface/modules
# copying build/lib/inspireface/modules/__init__.py -> build/bdist.linux-x86_64/egg/inspireface/modules
# copying build/lib/inspireface/modules/inspireface.py -> build/bdist.linux-x86_64/egg/inspireface/modules
# creating build/bdist.linux-x86_64/egg/inspireface/modules/core
# copying build/lib/inspireface/modules/core/__init__.py -> build/bdist.linux-x86_64/egg/inspireface/modules/core
# copying build/lib/inspireface/modules/core/native.py -> build/bdist.linux-x86_64/egg/inspireface/modules/core
# copying build/lib/inspireface/__init__.py -> build/bdist.linux-x86_64/egg/inspireface
# creating build/bdist.linux-x86_64/egg/test
# creating build/bdist.linux-x86_64/egg/test/performance
# copying build/lib/test/performance/test_lfw_precision.py -> build/bdist.linux-x86_64/egg/test/performance
# copying build/lib/test/performance/__init__.py -> build/bdist.linux-x86_64/egg/test/performance
# copying build/lib/test/test_settings.py -> build/bdist.linux-x86_64/egg/test
# creating build/bdist.linux-x86_64/egg/test/unit
# copying build/lib/test/unit/test_tracker_module.py -> build/bdist.linux-x86_64/egg/test/unit
# copying build/lib/test/unit/test_base_module.py -> build/bdist.linux-x86_64/egg/test/unit
# copying build/lib/test/unit/__init__.py -> build/bdist.linux-x86_64/egg/test/unit
# copying build/lib/test/unit/test_recognition_module.py -> build/bdist.linux-x86_64/egg/test/unit
# copying build/lib/test/__init__.py -> build/bdist.linux-x86_64/egg/test
# copying build/lib/test/test_utilis.py -> build/bdist.linux-x86_64/egg/test
# creating build/bdist.linux-x86_64/egg/test/integration
# copying build/lib/test/integration/__init__.py -> build/bdist.linux-x86_64/egg/test/integration
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/param.py to param.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/utils/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/utils/resource.py to resource.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/exception.py to exception.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/herror.py to herror.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/inspireface.py to inspireface.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/core/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/modules/core/native.py to native.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/inspireface/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/performance/test_lfw_precision.py to test_lfw_precision.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/performance/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/test_settings.py to test_settings.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/unit/test_tracker_module.py to test_tracker_module.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/unit/test_base_module.py to test_base_module.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/unit/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/unit/test_recognition_module.py to test_recognition_module.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/test_utilis.py to test_utilis.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/test/integration/__init__.py to __init__.cpython-38.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying inspireface.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying inspireface.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying inspireface.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying inspireface.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying inspireface.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# inspireface.modules.core.__pycache__.native.cpython-38: module references __file__
# test.__pycache__.test_settings.cpython-38: module references __file__
# creating 'dist/inspireface-1.2.3-py3.8.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing inspireface-1.2.3-py3.8.egg
# creating /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg
# Extracting inspireface-1.2.3-py3.8.egg to /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Adding inspireface 1.2.3 to easy-install.pth file
# detected new path './inspireface-1.2.3-py3.8.egg'
#
# Installed /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg
# Processing dependencies for inspireface==1.2.3
# Searching for modelscope==1.36.3
# Best match: modelscope 1.36.3
# Processing modelscope-1.36.3-py3.8.egg
# Adding modelscope 1.36.3 to easy-install.pth file
# Installing modelscope script to /home/iwake/.conda/envs/ifpy38/bin
# Installing ms script to /home/iwake/.conda/envs/ifpy38/bin
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/modelscope-1.36.3-py3.8.egg
# Searching for filelock==3.29.0
# Best match: filelock 3.29.0
# Processing filelock-3.29.0-py3.8.egg
# Adding filelock 3.29.0 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/filelock-3.29.0-py3.8.egg
# Searching for loguru==0.7.3
# Best match: loguru 0.7.3
# Adding loguru 0.7.3 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for numpy==1.24.4
# Best match: numpy 1.24.4
# Adding numpy 1.24.4 to easy-install.pth file
# Installing f2py script to /home/iwake/.conda/envs/ifpy38/bin
# Installing f2py3 script to /home/iwake/.conda/envs/ifpy38/bin
# Installing f2py3.8 script to /home/iwake/.conda/envs/ifpy38/bin
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for urllib3==2.2.3
# Best match: urllib3 2.2.3
# Adding urllib3 2.2.3 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for tqdm==4.67.3
# Best match: tqdm 4.67.3
# Adding tqdm 4.67.3 to easy-install.pth file
# Installing tqdm script to /home/iwake/.conda/envs/ifpy38/bin
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for setuptools==75.1.0
# Best match: setuptools 75.1.0
# Adding setuptools 75.1.0 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for requests==2.32.4
# Best match: requests 2.32.4
# Adding requests 2.32.4 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for packaging==24.1
# Best match: packaging 24.1
# Adding packaging 24.1 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/setuptools/_vendor
# Searching for certifi==2026.4.22
# Best match: certifi 2026.4.22
# Adding certifi 2026.4.22 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for idna==3.13
# Best match: idna 3.13
# Adding idna 3.13 to easy-install.pth file
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Searching for charset-normalizer==3.4.7
# Best match: charset-normalizer 3.4.7
# Adding charset-normalizer 3.4.7 to easy-install.pth file
# Installing normalizer script to /home/iwake/.conda/envs/ifpy38/bin
#
# Using /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages
# Finished processing dependencies for inspireface==1.2.3

# %%
# cpu to ./inspireface/modules/core/libs/linux/x64/
# Copy the compiled dynamic library to the corresponding system architecture directory
# !cd /kaggle/temp/InspireFace/python \
    && mkdir -p /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg/inspireface/modules/core/libs/linux/x64/ \
    && cp ../build/inspireface-linux/InspireFace/lib/libInspireFace.so \
    ./inspireface/modules/core/libs/linux/x64/

# %%
# gpu to ./inspireface/modules/core/libs/linux/x64/
# Copy the compiled dynamic library to the corresponding system architecture directory
# !cd /kaggle/temp/InspireFace/python \
    && mkdir -p /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg/inspireface/modules/core/libs/linux/x64/ \
    && cp ../build/inspireface-linux-tensorrt-cuda12.2_ubuntu22.04/InspireFace/lib/libInspireFace.so \
    ./inspireface/modules/core/libs/linux/x64/

# %%
# cpu to inspireface-1.2.3-py3.8.egg
# Copy the compiled dynamic library to the corresponding system architecture directory
# !cd /kaggle/temp/InspireFace/python \
    && mkdir -p /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg/inspireface/modules/core/libs/linux/x64/ \
    && cp ../build/inspireface-linux/InspireFace/lib/libInspireFace.so \
    /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg/inspireface/modules/core/libs/linux/x64/

# %%
# gpu to inspireface-1.2.3-py3.8.egg
# Copy the compiled dynamic library to the corresponding system architecture directory
# !cd /kaggle/temp/InspireFace/python \
    && mkdir -p /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg/inspireface/modules/core/libs/linux/x64/ \
    && cp ../build/inspireface-linux-tensorrt-cuda12.2_ubuntu22.04/InspireFace/lib/libInspireFace.so \
    /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/inspireface-1.2.3-py3.8.egg/inspireface/modules/core/libs/linux/x64/

# %% [markdown]
# ## run demo

# %%
# !LD_LIBRARY_PATH=/opt/tensorrt/lib:$LD_LIBRARY_PATH \
    python demo.py
# Out:
# InspireFace SDK [Community Edition] v1.2.3 (Built: May 11 2026 22:06:34) [Linux/x86_64/GCC 11.4.0] Backend: TensorRT(CUDA) InspireCV[CPU]
# ModelScope import successful
# Downloading model 'Pikachu' from ModelScope...
# Downloading Model from https://www.modelscope.cn to directory: /home/iwake/.inspireface/ms/tunmxy/InspireFace
# ModelScope download completed: /home/iwake/.inspireface/ms/tunmxy/InspireFace/Pikachu
# == Load Pikachu-t4.0, Version: 4.0, Release: 2025-06-08 ==
# Successfully loaded similarity converter config:
#  	 threshold: 0.480000
#  	 middle_score: 0.600000
#  	 steepness: 8.000000
#  	 output_min: 0.010000
#  	 output_max: 1.000000
# Successfully loaded resources
# The device support i8sdot:0, support fp16:0, support i8mm: 0
# Detected 6 faces

# %%
# !LD_LIBRARY_PATH=/opt/tensorrt/lib:$LD_LIBRARY_PATH \
    python /kaggle/temp/InspireFace/python/sample_face_detection.py \
    --show /kaggle/temp/insightface/python-package/insightface/data/images/t1.jpg
# Out:
# InspireFace SDK [Community Edition] v1.2.3 (Built: May 11 2026 22:06:34) [Linux/x86_64/GCC 11.4.0] Backend: TensorRT(CUDA) InspireCV[CPU]
# ModelScope import successful
# Downloading model 'Pikachu' from ModelScope...
# Downloading Model from https://www.modelscope.cn to directory: /home/iwake/.inspireface/ms/tunmxy/InspireFace
# ModelScope download completed: /home/iwake/.inspireface/ms/tunmxy/InspireFace/Pikachu
# == Load Pikachu-t4.0, Version: 4.0, Release: 2025-06-08 ==
# Successfully loaded similarity converter config:
#  	 threshold: 0.480000
#  	 middle_score: 0.600000
#  	 steepness: 8.000000
#  	 output_min: 0.010000
#  	 output_max: 1.000000
# Successfully loaded resources
# The device support i8sdot:0, support fp16:0, support i8mm: 0
# [FaceInformation(track_id=-1, track_count=1, detection_confidence=0.8557202219963074, location=(465, 301, 573, 413), roll=13.17111873626709, yaw=-4.846005439758301, pitch=-23.736135482788086), FaceInformation(track_id=-1, track_count=1, detection_confidence=0.8465124368667603, location=(908, 95, 1016, 206), roll=-15.194936752319336, yaw=-58.31640625, pitch=-9.559187889099121), FaceInformation(track_id=-1, track_count=1, detection_confidence=0.7918592095375061, location=(62, 286, 165, 399), roll=-25.717243194580078, yaw=4.3928399085998535, pitch=-0.9132331609725952), FaceInformation(track_id=-1, track_count=1, detection_confidence=0.8167707920074463, location=(280, 172, 374, 264), roll=-28.238710403442383, yaw=-24.348857879638672, pitch=1.0309385061264038), FaceInformation(track_id=-1, track_count=1, detection_confidence=0.905080258846283, location=(749, 385, 849, 475), roll=8.86207389831543, yaw=-24.656766891479492, pitch=-24.575326919555664), FaceInformation(track_id=-1, track_count=1, detection_confidence=0.8636342883110046, location=(1134, 304, 1227, 397), roll=-3.633402109146118, yaw=-11.692360877990723, pitch=-3.582533121109009)]
# face detection: 6 found
# ========================================
# idx: 0
# detection confidence: 0.8557202219963074
# roll: 13.17111873626709, yaw: -4.846005439758301, pitch: -23.736135482788086
# ========================================
# idx: 1
# detection confidence: 0.8465124368667603
# roll: -15.194936752319336, yaw: -58.31640625, pitch: -9.559187889099121
# ========================================
# idx: 2
# detection confidence: 0.7918592095375061
# roll: -25.717243194580078, yaw: 4.3928399085998535, pitch: -0.9132331609725952
# ========================================
# idx: 3
# detection confidence: 0.8167707920074463
# roll: -28.238710403442383, yaw: -24.348857879638672, pitch: 1.0309385061264038
# ========================================
# idx: 4
# detection confidence: 0.905080258846283
# roll: 8.86207389831543, yaw: -24.656766891479492, pitch: -24.575326919555664
# ========================================
# idx: 5
# detection confidence: 0.8636342883110046
# roll: -3.633402109146118, yaw: -11.692360877990723, pitch: -3.582533121109009
# [FaceExtended(rgb_liveness_confidence=0.8855262398719788, mask_confidence=0.0020095561631023884, quality_confidence=0.7427127957344055, left_eye_status_confidence=1.0, right_eye_status_confidence=0.9999997615814209, action_normal=1, action_jaw_open=0, action_shake=0, action_blink=0, action_head_raise=0, race=4, gender=1, age_bracket=3, emotion=1), FaceExtended(rgb_liveness_confidence=0.9649801254272461, mask_confidence=0.026761028915643692, quality_confidence=0.8281612992286682, left_eye_status_confidence=3.783176794058818e-07, right_eye_status_confidence=0.9999996423721313, action_normal=1, action_jaw_open=0, action_shake=0, action_blink=0, action_head_raise=0, race=4, gender=1, age_bracket=3, emotion=0), FaceExtended(rgb_liveness_confidence=0.9551573395729065, mask_confidence=0.019738342612981796, quality_confidence=0.7193329930305481, left_eye_status_confidence=4.3944128860557205e-17, right_eye_status_confidence=0.05105838179588318, action_normal=1, action_jaw_open=0, action_shake=0, action_blink=0, action_head_raise=0, race=4, gender=0, age_bracket=3, emotion=0), FaceExtended(rgb_liveness_confidence=0.9743791222572327, mask_confidence=0.0061996132135391235, quality_confidence=0.6626416444778442, left_eye_status_confidence=0.6402566432952881, right_eye_status_confidence=0.9739475250244141, action_normal=1, action_jaw_open=0, action_shake=0, action_blink=0, action_head_raise=0, race=4, gender=0, age_bracket=3, emotion=0), FaceExtended(rgb_liveness_confidence=0.5421197414398193, mask_confidence=0.0150318443775177, quality_confidence=0.8028392791748047, left_eye_status_confidence=0.0022291585337370634, right_eye_status_confidence=2.2996260895524756e-07, action_normal=1, action_jaw_open=0, action_shake=0, action_blink=0, action_head_raise=0, race=4, gender=1, age_bracket=3, emotion=1), FaceExtended(rgb_liveness_confidence=0.7874172329902649, mask_confidence=0.04259159415960312, quality_confidence=0.7201591730117798, left_eye_status_confidence=7.602800167205714e-08, right_eye_status_confidence=3.65730466744818e-11, action_normal=1, action_jaw_open=0, action_shake=0, action_blink=0, action_head_raise=0, race=4, gender=0, age_bracket=3, emotion=1)]
# ========================================
# idx: 0
# quality: 0.7427127957344055
# rgb liveness: 0.8855262398719788
# face mask: 0.0020095561631023884
# face eyes status: left eye: 1.0 right eye: 0.9999997615814209
# gender: Male
# race: White
# age: 20-29 years old
# emotion: Happy
# ========================================
# idx: 1
# quality: 0.8281612992286682
# rgb liveness: 0.9649801254272461
# face mask: 0.026761028915643692
# face eyes status: left eye: 3.783176794058818e-07 right eye: 0.9999996423721313
# gender: Male
# race: White
# age: 20-29 years old
# emotion: Neutral
# ========================================
# idx: 2
# quality: 0.7193329930305481
# rgb liveness: 0.9551573395729065
# face mask: 0.019738342612981796
# face eyes status: left eye: 4.3944128860557205e-17 right eye: 0.05105838179588318
# gender: Female
# race: White
# age: 20-29 years old
# emotion: Neutral
# ========================================
# idx: 3
# quality: 0.6626416444778442
# rgb liveness: 0.9743791222572327
# face mask: 0.0061996132135391235
# face eyes status: left eye: 0.6402566432952881 right eye: 0.9739475250244141
# gender: Female
# race: White
# age: 20-29 years old
# emotion: Neutral
# ========================================
# idx: 4
# quality: 0.8028392791748047
# rgb liveness: 0.5421197414398193
# face mask: 0.0150318443775177
# face eyes status: left eye: 0.0022291585337370634 right eye: 2.2996260895524756e-07
# gender: Male
# race: White
# age: 20-29 years old
# emotion: Happy
# ========================================
# idx: 5
# quality: 0.7201591730117798
# rgb liveness: 0.7874172329902649
# face mask: 0.04259159415960312
# face eyes status: left eye: 7.602800167205714e-08 right eye: 3.65730466744818e-11
# gender: Female
# race: White
# age: 20-29 years old
# emotion: Happy
# QFontDatabase: Cannot find font directory /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/iwake/.conda/envs/ifpy38/lib/python3.8/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
#
# Save annotated image to tmp/det.jpg
