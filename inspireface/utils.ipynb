# %% [markdown]
# ## docker

# %%
# build
# !sudo docker-compose up -d build-tensorrt-cuda12-ubuntu22

# %%
# exec(get into container)
# !sudo docker-compose run build-tensorrt-cuda12-ubuntu22 bash

# %% [markdown]
# ## env

# %%
# recommand use gcc11 or gcc12
# !yay -S gcc12

# %%
# list gcc version
# !ls /usr/bin/gcc*
# !gcc -v
# !ls -l $(which gcc)

# %%
！sudo pacman -S cuda cudnn

# %%
！mkdir -p ~/cuda-compat

！ln -s /usr/bin/gcc-12 ~/cuda-compat/gcc
！ln -s /usr/bin/g++-12 ~/cuda-compat/g++

# %%
# !PATH=~/cuda-compat:$PATH yay -S tensorrt

# %% [markdown]
# ## model

# %%
# !cd /kaggle/temp/InspireFace \
    && bash command/download_models_general.sh Megatron

# %%
# !cd /kaggle/temp/InspireFace \
    && bash command/download_models_general.sh Megatron_TRT

# %% [markdown]
# ## src

# %%
# cp herror.h to c_api, if needed
# !cd /kaggle/temp/InspireFace \
    && cp ./cpp/inspireface/include/inspireface/herror.h ./cpp/inspireface/c_api/herror.h
